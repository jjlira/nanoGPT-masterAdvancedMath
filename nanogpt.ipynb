# %% [markdown]
# # AASD 4016: Advanced Applied Mathematical Concepts for Deep Learning
# ### Project 01: "Customizing nanoGPT to Generate Text in the Style of President Donal Trump"
#
#  - Jose Lira (101426814)
#  - Tuo Xin (101409861)

# %% [markdown]
# ### Problem statement
# In this project, we tried to fine tune nanogpt with Donald Trump's rally speeches. We try to figure out if the model can pick up Donald Trump's speaking style. And see how large the dataset should be to avoid overfitting and produce decent result.

# %% [markdown]
# ### Dataset
# We used Kaggle Dataset of full-length speeches that Donald Trump gave in 35 of his rallies.
#
# We used one/five/all of them as the input to the model and benchmarked the result in the table below.
#
# Dataset Link: https://www.kaggle.com/datasets/christianlillelund/donald-trumps-rallies

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Environment
#
# •	Windows 11
#
# •	Python 3.10.9
#
# •	PyTorch: torch-1.13.1+cu116 CUDA:0 (NVIDIA GeForce RTX 2060, 6144MiB)
#
# •	VSCode 1.75.1
#
# •	CUDA: 11.6, V11.6.55
#
# •	CUDNN 11.6
#
# •	GPU: NVIDIA GeForce RTX 2060
#
# •	CPU: 06 Intel Core i7-10750 @2.6Ghz (12 CPUs, 32 GB RAM)

# %% [markdown]
# ### Training
#
# We run 06 experiments in order to tune and test the nanoGPT model providing combinations of parameters like learning rate, maximum iterations, and amount of full-text speeches provided as input to the model.
#
# The running time range from 1 hours (simplest model) to 6 hours (using the 35 speeches and 100 iterations).

# %% [markdown]
# ### Results

# %% [markdown]
# The generated text from tinetuned model with one or five speeches are not readable. Big corpus helps build a more robust model. 'The finetuned model' below refers to the model fine-tuned with 35 speeches.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Experiment 01
# Our base model with only one speech, 32 gradient accumulated steps and a low learning rate of 3e-5.
# We obtain a validation loss of 10.11 and the results were not as expexted as the text has no sense.
# ### Sample of Experiment 01:
# FAM,'s that... league,vesoğten,,, Trying, inconvenient...... OECD......,...,,.,.,.,. legalizing...,,,,. legalizing562,.ourkeadvertisement,..,..,,562. Ethnic strategic,. pedd,.. Mental Electoraligans,,pend. mere,, RecipeShin,,...,.,,, gracious whole. to mattress, Transparency.,. enginesjon irritating,,,,,. ,. swore....  , Header 1904.. Electric,..,,,....,. Brett,,,,,,, crowdfunding,, the,.. the,,,,,,952.,,. motherboard,,...,,igans Resource......,.hole,,,,TL.,,,.'s, imagining you.....,,,,,,..... legalizing.,,,... fruitful,.,,.,,,FIN I.downs,,,...,,hidden,, imagining,..,, legalizing,,.. winner..oldown,.,, dealer  ,,,,..,, Site],[,,... 1904 Headerretched,.advertisement WCS..,,,,,,,..,,,.. pushed,,,, wre,,,,,,,. quir,,.,,....... inconvenient,,,,,,,,,,,,,... paper. 1904. squat the,,,,.. I. scaff.,,.... visualize.,,,. the,,..,, Electric, roasted,,, Immigration... dirty,,,1987,,,,,.,  urgent. Collins,,.,,, Sigma., you,,,,..,. example, inconsistencies're,.,,,,,, siph, fill wre, Dee,,..,,, swore,...,,,,. blending,.him,,.,.,,.. inventor.,,, paper Tup.,,,.,..,,
#  he was a horrible, but they like." I times. He's down to get them, and over and we're the same and he was a minute, "I'll tell you, did that what happened, let that they're what they're going to be great, the wall. We don't get rid of these people that's, look at that one, "You're going to do." And we're the history of it's going to say, that's always going to imagine a lot of say, because the history of China, "We will be a great, but we've done an little bit, "Oh, back to do twoWell, right now we're going to be very much." They had a little while. We will be here up, we're not the polls, "What. And we're going to do it. It's not going to have to the world, we're allowed to?" But we're going to bring them over our country. I said,000 so if it? Because he said, â€¦ What we're very good, it for, and we have to one of your country, because they're going to do we're great say, he's not would not the Constitution of the most important to win that they're not I'm not going to have a the Democrats are going to do as a parking, do it, and a lot of our military said, there, and two days, we have a great job. Oh, "Tra down Obama. I'm not like to have been everybody. We have a friend of on the Democrats are going to do it, history of it's done. I said, we have to do it. They'd going to the president, because they put them back. You know about it's like are going to raise your life, I'm not going to do that? For years. But even want to happen. We've ended the America made a great people of the kids. I do, but we're going to fake news are going to be so many people it. And I think we're going to went out and I don't like a lot of them. But had to do it. I'd see the largest little bit, we're going to come in the most, I said, "How build it ever done get a horrible people remember that, we've have your next single business, I said, and they are, in the Biden's a
# ### Experiment 05
# We increased the number of speechs to 35 and increased the maximum iterations to 100 obtaining an improvement of the validation loss to 4.97.
# ###  Sample of Experiment 05
#  But these companies. It's impeach him. Where is we have any. Let me. They're getting more. We did a lot of these people, they're against them. We so we had a great deal. You have a great people. They. And we got to be even got a lot of people. But we're so. And I don't have a lot of them. You talk about. And by the attack is for that's going to go into the same way, the middle. You know what a nice. And we got it's by the Senate. We're going to get all over the whole great. He's going to thank you look at a big deal. It's back. Are you bad as us. Did you go home and they made a tree and come in Michigan. We had a lot of you have. I have a half. The biggest because we're doing great deal. with them have a free over. We will be a great with your cars. They read it. Then they're already only they were to have thought you got a little, it's happening. She's will be so opposed to be a to be with nothing. It's other day, when they'll be there. But you know, " ICE, I like I'm not bringing, we have to have it's what? We don't do it. And now, I mean somebody said, they've done that is? And you said, because again, time for your state. He's not going to do it's ever had a disaster." And it's going to do. And I think he said, I've been a great. He's a lot of our country. We're the â€¦ Now, right. They're spending? For me. But all of on a minute. But and they love it. You have a good again. He's an ad. We're going to be been a lot of here. We're did it was a little bit, right? No, we'll be in the world. You have to get up, it. It's a great. There's really said, and you know, "We want to do a little bit. We love you, and here to have to go into our other countries, I'm going to leave. Let's their election? The whole thing. We get in the greatest economy's going up. I'm going to
# ### Experiment 06
# We increased the learning rate to 3e-4 and increased the iterations to 120. The validation loss was 4.43 and the text is legible now, somewhat in the style of Donald Trump.
#
# ![image.png](attachment:image.png)
#
# As we expected the best result was in experiment Below are the result we got from the best fine-tuned model we have vs pretrained nanogpt base model. A significant style change is observable.
#
# ### Lets run Experiment 06 with starting words: "How to make America great again?"
#
# The generate text from nanogpt:

# %%
! python sample.py --init_from=gpt2 --start="How to make America great again?"  --num_samples=1 --max_new_tokens=200
# Out:
# modelpy running
# Overriding: init_from = gpt2
# Overriding: start = How to make America great again?
# Overriding: num_samples = 1
# Overriding: max_new_tokens = 200
# loading weights from pretrained gpt: gpt2
# forcing vocab_size=50257, block_size=1024, bias=True
# overriding dropout rate to 0.0
# WARNING: using slow attention. Flash Attention requires PyTorch >= 2.0
# WARNING: using slow attention. Flash Attention requires PyTorch >= 2.0
# WARNING: using slow attention. Flash Attention requires PyTorch >= 2.0
# WARNING: using slow attention. Flash Attention requires PyTorch >= 2.0
# WARNING: using slow attention. Flash Attention requires PyTorch >= 2.0
# WARNING: using slow attention. Flash Attention requires PyTorch >= 2.0
# WARNING: using slow attention. Flash Attention requires PyTorch >= 2.0
# WARNING: using slow attention. Flash Attention requires PyTorch >= 2.0
# WARNING: using slow attention. Flash Attention requires PyTorch >= 2.0
# ...

# %% [markdown]
# The generated text from fine-tuned model:

# %%
! python sample.py --init_from=resume --start="How to make America great again?"  --num_samples=1 --max_new_tokens=200
# Out:
# modelpy running
# Overriding: init_from = resume
# Overriding: start = How to make America great again?
# Overriding: num_samples = 1
# Overriding: max_new_tokens = 200
# WARNING: using slow attention. Flash Attention requires PyTorch >= 2.0
# WARNING: using slow attention. Flash Attention requires PyTorch >= 2.0
# WARNING: using slow attention. Flash Attention requires PyTorch >= 2.0
# WARNING: using slow attention. Flash Attention requires PyTorch >= 2.0
# WARNING: using slow attention. Flash Attention requires PyTorch >= 2.0
# WARNING: using slow attention. Flash Attention requires PyTorch >= 2.0
# WARNING: using slow attention. Flash Attention requires PyTorch >= 2.0
# WARNING: using slow attention. Flash Attention requires PyTorch >= 2.0
# WARNING: using slow attention. Flash Attention requires PyTorch >= 2.0
# WARNING: using slow attention. Flash Attention requires PyTorch >= 2.0
# WARNING: using slow attention. Flash Attention requires PyTorch >= 2.0
# ...

# %% [markdown]
# ### Summary

# %% [markdown]
# The model picked up two significant characters:
# 1. Use easy words: Danald Trump is famous for his habits of using easy words at the level of every kid can understand.
# 2. Short sentences: Compared to pretrained model trained from open webtext. Speeches contains lots of spoken short sentences.
#
# Model Problems:
# 1. Speeches are not training materials as the coherence between sentences is not good, compared to novals and webtexts.
# 2. Filler words and repetitive phrases interupts the flow. For example: "I took you on this fantastic journey. It's so much fun. They want to impeach you. They want to do worse than that. By the way, by the way, by the way, it doesn't really feel like we're being impeached." Note that 'by the way' repeated 3 times, which badly influences a generative model.
# 3. We need larger dataset to produce a better model.

# %% [markdown]
# ### Exploration

# %% [markdown]
# Then we put generated text to OpenAI ai text classififer that detect if a text is generated by an AI.
#
# Below are the results:
# Link: https://platform.openai.com/ai-text-classifier
#
# Interestingly, both generated text got the same result:
# The classifier considers the text to be unclear if it is AI-generated.

# %% [markdown]
# ### References
#
# - [1] Karpahty, "nanoGPT", (2023). URL:  https://github.com/karpathy/nanoGPT
# - [2] OpenAI, "AI Text Classifier", (2023). URL: https://platform.openai.com/ai-text-classifier
# - [3] Kaggle,"Donald Trump Rally Speeches" (2020). URL: https://www.kaggle.com/datasets/christianlillelund/donald-trumps-rallies
